# %%
# %run ../__init__.py

# %%
budget_df= pd.read_csv('../data/budget_df_cleaned1.csv')

# %%
from collections import Counter

result = Counter(" ".join(budget_df['combined_text'].astype(str)).split(" ")).items()

word_count = pd.DataFrame(list(result), columns=['word','counts'])

word_count = word_count.sort_values('word')

# %%
word_count.shape
# Out:
# (3352, 2)

# %%
words = word_count[word_count['counts'] < 10]

# %%
words_10 = word_count[word_count['counts'] > 10]

# %%
word_predictors
# Out:
# ['Object_Description',
#  'Text_2',
#  'SubFund_Description',
#  'Job_Title_Description',
#  'Text_3',
#  'Text_4',
#  'Sub_Object_Description',
#  'Location_Description',
#  'Function_Description',
#  'Facility_or_Department',
#  'Position_Extra',
#  'Program_Description',
#  'Fund_Description',
#  'Text_1']

# %%
text_1 = Counter(" ".join(budget_df['Object_Description'].astype(str)).split(" ")).items()

# %%
text_1 = pd.DataFrame(list(text_1), columns=['word','counts'])

# %%
text_1.shape
# Out:
# (503, 2)

# %%
text_1 = text_1.sort_values('word')

# %%
text_1 = text_1[text_1['counts'] > 10]

# %%
text_1
# Out:
#                word  counts
# 0                     49690
# 303           accnt      70
# 246         account      25
# 223      accountant      93
# 268            acct      92
# 211     acquisition     192
# 289        activity      97
# 35       additional   16872
# 234  administrative     288
# 276   administrator     189
# 192           adult     182
# 175     advertising      92
# 314            aide      19
# 138       allowance     715
# 239            apps      55
# 304           asset      37
# 49        assistant    2891
# 133        athletic     436
# 203        attorney      31
# 188              av      85
# 98            award     879
# 392          behalf      14
# 6           benefit   67030
# 96             bind     297
# 242           bldgs     160
# 279            bond      31
# 358         bonding      34
# 24            bonus    3371
# 54             book    3533
# 224      bookkeeper      93
# ..              ...     ...
# 323            term      19
# ...
