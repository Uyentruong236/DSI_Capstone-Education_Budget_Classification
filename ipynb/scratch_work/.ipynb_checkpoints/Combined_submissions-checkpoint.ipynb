# %%
# %run ../__init__.py

# %%
targets
# Out:
# ['Function',
#  'Use',
#  'Sharing',
#  'Reporting',
#  'Student_Type',
#  'Position_Type',
#  'Object_Type',
#  'Pre_K',
#  'Operating_Status']

# %%
budget_test = pd.read_csv('../data/budget_test.csv')
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
budget_test.head(20)
# Out:
#     Unnamed: 0                         Object_Description  \
# 0       180042                   Student Meals/Room/Other
# 1        28872               Extra Duty/Signing Bonus Pay
# 2       186915                      Professional Salaries
# 3       412396                      Professional Salaries
# 4       427740             Salaries for Support Personnel
# 5        69847                           General Supplies
# 6       358824                            Maint: Vehicles
# 7       254148               Extra Duty/Signing Bonus Pay
# 8          296                           General Supplies
# 9       416755             Salaries for Support Personnel
# 10      179714             Salaries for Support Personnel
# 11      285896             Salaries for Support Personnel
# 12      265808  Reading Materials including Library Books
# 13      197775                      Professional Salaries
# 14      204524               Extra Duty/Signing Bonus Pay
# ...

# %%
budget_test.head()
# Out:
#    Unnamed: 0              Object_Description         Program_Description  \
# 0      180042        Student Meals/Room/Other  Basic Educational Services
# 1       28872    Extra Duty/Signing Bonus Pay               Undistributed
# 2      186915           Professional Salaries         Bilingual Education
# 3      412396           Professional Salaries         Bilingual Education
# 4      427740  Salaries for Support Personnel               Undistributed
#
#   SubFund_Description Job_Title_Description Facility_or_Department  \
# 0                 NaN                   NaN                    NaN
# 1                 NaN       CHEERLEADER DIR                    NaN
# 2                 NaN          T-EL 1ST BIL                    NaN
# 3                 NaN          T-EL 2ND BIL                    NaN
# 4                 NaN        CLERK III- SCH                    NaN
#
#                       Sub_Object_Description Location_Description  FTE  \
# ...

# %%
Function = pd.read_csv('../data/function_probability.csv', index_col=0)
Use = pd.read_csv('../data/use_probability.csv', index_col=0)
Sharing = pd.read_csv('../data/sharing_probability.csv', index_col=0)
Reporting = pd.read_csv('../data/reporting_probability.csv', index_col=0)
Student_Type = pd.read_csv('../data/student_type_probability.csv', index_col=0)
Position_Type = pd.read_csv('../data/position_probability.csv', index_col=0)
Object_Type = pd.read_csv('../data/object_probability.csv', index_col=0)
Pre_K = pd.read_csv('../data/preK_probability.csv', index_col=0)
Operating_Status = pd.read_csv('../data/op_stat_probability.csv', index_col=0)

# %%
results = pd.concat([budget_test, Function, Object_Type, Operating_Status, Position_Type, Pre_K, Reporting,\
                     Sharing, Student_Type, Use], axis = 1)

# %%
results.shape
# Out:
# (50064, 121)

# %%
results = results.drop(predictors, axis=1)

# %%
results.shape
# Out:
# (50064, 105)

# %%
results.to_csv('initial_submission.csv')
